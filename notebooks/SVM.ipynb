# %%
import pickle

with open("../data/preprocessed_data_outlier_vae_enhanced.pkl", "rb") as f:
    preprocessed_data = pickle.load(f)

X_train_scaled = preprocessed_data["X_train"]
X_val_scaled = preprocessed_data["X_val"]
X_test_scaled = preprocessed_data["X_test"]
y_train = preprocessed_data["y_train"]
y_val = preprocessed_data["y_val"]
y_test = preprocessed_data["y_test"]

print(X_train_scaled.shape)
print(X_val_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (1096, 101)
# (235, 101)
# (236, 101)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

RANDOM_SEED = 559

svm_baseline = SVC(kernel="rbf", random_state=RANDOM_SEED)
svm_baseline.fit(X_train_scaled, y_train)

y_val_pred = svm_baseline.predict(X_val_scaled)

print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print("Validation Precision:", precision_score(y_val, y_val_pred, pos_label=1))
print("Validation Recall:", recall_score(y_val, y_val_pred, pos_label=1))
print("Validation F1-score:", f1_score(y_val, y_val_pred, pos_label=1))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.9361702127659575
# Validation Precision: 0.0
# Validation Recall: 0.0
# Validation F1-score: 0.0
# Confusion Matrix:
#  [[220   0]
#  [ 15   0]]
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

RANDOM_SEED = 559

svm_weighted = SVC(kernel="rbf", class_weight="balanced", random_state=RANDOM_SEED)
svm_weighted.fit(X_train_scaled, y_train)

y_val_pred = svm_weighted.predict(X_val_scaled)

print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print("Validation Precision:", precision_score(y_val, y_val_pred, pos_label=1, zero_division=0))
print("Validation Recall:", recall_score(y_val, y_val_pred, pos_label=1, zero_division=0))
print("Validation F1-score:", f1_score(y_val, y_val_pred, pos_label=1, zero_division=0))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.902127659574468
# Validation Precision: 0.16666666666666666
# Validation Recall: 0.13333333333333333
# Validation F1-score: 0.14814814814814814
# Confusion Matrix:
#  [[210  10]
#  [ 13   2]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

for w in [5, 10, 15]:
    svm_model = SVC(
        kernel="rbf",
        class_weight={-1: 1, 1: w},
        random_state=RANDOM_SEED
    )

    svm_model.fit(X_train_scaled, y_train)
    y_val_pred = svm_model.predict(X_val_scaled)

    print(f"\nClass weight {{-1:1, 1:{w}}}")
    print("Accuracy:", accuracy_score(y_val, y_val_pred))
    print("Precision:", precision_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("Recall:", recall_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("F1-score:", f1_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Class weight {-1:1, 1:5}
# Accuracy: 0.9319148936170213
# Precision: 0.3333333333333333
# Recall: 0.06666666666666667
# F1-score: 0.1111111111111111
# Confusion Matrix:
#  [[218   2]
#  [ 14   1]]
#
# Class weight {-1:1, 1:10}
# Accuracy: 0.9276595744680851
# Precision: 0.25
# Recall: 0.06666666666666667
# F1-score: 0.10526315789473684
# Confusion Matrix:
#  [[217   3]
#  [ 14   1]]
#
# Class weight {-1:1, 1:15}
# Accuracy: 0.9276595744680851
# Precision: 0.25
# Recall: 0.06666666666666667
# F1-score: 0.10526315789473684
# Confusion Matrix:
#  [[217   3]
#  [ 14   1]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

for c in [0.1, 1, 10, 100]:
    svm_model = SVC(
        kernel="linear",
        C=c,
        class_weight="balanced",
        random_state=RANDOM_SEED
    )

    svm_model.fit(X_train_scaled, y_train)
    y_val_pred = svm_model.predict(X_val_scaled)

    print(f"\nLinear SVM, C={c}")
    print("Accuracy:", accuracy_score(y_val, y_val_pred))
    print("Precision:", precision_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("Recall:", recall_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("F1-score:", f1_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Linear SVM, C=0.1
# Accuracy: 0.7021276595744681
# Precision: 0.07692307692307693
# Recall: 0.3333333333333333
# F1-score: 0.125
# Confusion Matrix:
#  [[160  60]
#  [ 10   5]]
#
# Linear SVM, C=1
# Accuracy: 0.7021276595744681
# Precision: 0.07692307692307693
# Recall: 0.3333333333333333
# F1-score: 0.125
# Confusion Matrix:
#  [[160  60]
#  [ 10   5]]
#
# Linear SVM, C=10
# Accuracy: 0.7063829787234043
# Precision: 0.05
# Recall: 0.2
# F1-score: 0.08
# Confusion Matrix:
#  [[163  57]
#  [ 12   3]]
#
# Linear SVM, C=100
# Accuracy: 0.7148936170212766
# Precision: 0.05172413793103448
# Recall: 0.2
# F1-score: 0.0821917808219178
# Confusion Matrix:
#  [[165  55]
#  [ 12   3]]

# %%
for c in [0.01, 0.05, 0.1, 0.2, 0.5]:
    svm_model = SVC(
        kernel="linear",
        C=c,
        class_weight="balanced",
        random_state=RANDOM_SEED
    )

    svm_model.fit(X_train_scaled, y_train)
    y_val_pred = svm_model.predict(X_val_scaled)

    print(f"\nLinear SVM, C={c}")
    print("Accuracy:", accuracy_score(y_val, y_val_pred))
    print("Precision:", precision_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("Recall:", recall_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("F1-score:", f1_score(y_val, y_val_pred, pos_label=1, zero_division=0))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Linear SVM, C=0.01
# Accuracy: 0.7021276595744681
# Precision: 0.08955223880597014
# Recall: 0.4
# F1-score: 0.14634146341463414
# Confusion Matrix:
#  [[159  61]
#  [  9   6]]
#
# Linear SVM, C=0.05
# Accuracy: 0.7021276595744681
# Precision: 0.07692307692307693
# Recall: 0.3333333333333333
# F1-score: 0.125
# Confusion Matrix:
#  [[160  60]
#  [ 10   5]]
#
# Linear SVM, C=0.1
# Accuracy: 0.7021276595744681
# Precision: 0.07692307692307693
# Recall: 0.3333333333333333
# F1-score: 0.125
# Confusion Matrix:
#  [[160  60]
#  [ 10   5]]
#
# Linear SVM, C=0.2
# Accuracy: 0.7063829787234043
# Precision: 0.10294117647058823
# Recall: 0.4666666666666667
# F1-score: 0.1686746987951807
# Confusion Matrix:
#  [[159  61]
#  [  8   7]]
#
# Linear SVM, C=0.5
# Accuracy: 0.7021276595744681
# Precision: 0.08955223880597014
# Recall: 0.4
# F1-score: 0.14634146341463414
# Confusion Matrix:
#  [[159  61]
#  [  9   6]]

# %%
best_svm = SVC(
    kernel="linear",
    C=0.1,
    class_weight="balanced",
    random_state=RANDOM_SEED
)

best_svm.fit(X_train_scaled, y_train)
y_test_pred = best_svm.predict(X_test_scaled)

print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
print("Test Precision:", precision_score(y_test, y_test_pred, pos_label=1, zero_division=0))
print("Test Recall:", recall_score(y_test, y_test_pred, pos_label=1, zero_division=0))
print("Test F1-score:", f1_score(y_test, y_test_pred, pos_label=1, zero_division=0))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Accuracy: 0.7542372881355932
# Test Precision: 0.18181818181818182
# Test Recall: 0.75
# Test F1-score: 0.2926829268292683
# Confusion Matrix:
#  [[166  54]
#  [  4  12]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

best_model = None
best_score = -1
best_setting = None

# 你可以自己再加或減
c_list = [0.01, 0.05, 0.1, 0.2, 0.5, 1]
weight_list = [
    "balanced",
    {-1: 1, 1: 5},
    {-1: 1, 1: 10},
    {-1: 1, 1: 15},
    {-1: 1, 1: 20},
]

results = []

for c in c_list:
    for w in weight_list:
        svm_model = SVC(
            kernel="linear",
            C=c,
            class_weight=w,
            random_state=RANDOM_SEED
        )

        svm_model.fit(X_train_scaled, y_train)
        y_val_pred = svm_model.predict(X_val_scaled)

        acc = accuracy_score(y_val, y_val_pred)
        prec = precision_score(y_val, y_val_pred, pos_label=1, zero_division=0)
        rec = recall_score(y_val, y_val_pred, pos_label=1, zero_division=0)
        f1 = f1_score(y_val, y_val_pred, pos_label=1, zero_division=0)
        cm = confusion_matrix(y_val, y_val_pred)

        results.append({
            "C": c,
            "class_weight": w,
            "accuracy": acc,
            "precision": prec,
            "recall": rec,
            "f1": f1,
            "confusion_matrix": cm
        })

        print(f"\nLinear SVM | C={c} | class_weight={w}")
        print("Accuracy:", acc)
        print("Precision:", prec)
        print("Recall:", rec)
        print("F1-score:", f1)
        print("Confusion Matrix:\n", cm)

        # 如果你最在意抓到 fail，就優先用 recall 當標準
        # 若 recall 相同，再比 F1
        score = (rec, f1)

        if score > best_score if isinstance(best_score, tuple) else (rec, f1) > (-1, -1):
            best_score = score
            best_model = svm_model
            best_setting = {
                "C": c,
                "class_weight": w,
                "accuracy": acc,
                "precision": prec,
                "recall": rec,
                "f1": f1,
                "confusion_matrix": cm
            }

print("\n" + "="*50)
print("Best validation setting:")
print("C:", best_setting["C"])
print("class_weight:", best_setting["class_weight"])
print("Accuracy:", best_setting["accuracy"])
print("Precision:", best_setting["precision"])
print("Recall:", best_setting["recall"])
print("F1-score:", best_setting["f1"])
print("Confusion Matrix:\n", best_setting["confusion_matrix"])
# Out:
# Linear SVM | C=0.01 | class_weight=balanced
# Accuracy: 0.7021276595744681
# Precision: 0.08955223880597014
# Recall: 0.4
# F1-score: 0.14634146341463414
# Confusion Matrix:
#  [[159  61]
#  [  9   6]]
#
# Linear SVM | C=0.01 | class_weight={-1: 1, 1: 5}
# Accuracy: 0.8723404255319149
# Precision: 0.058823529411764705
# Recall: 0.06666666666666667
# F1-score: 0.0625
# Confusion Matrix:
#  [[204  16]
#  [ 14   1]]
#
# Linear SVM | C=0.01 | class_weight={-1: 1, 1: 10}
# Accuracy: 0.7574468085106383
# Precision: 0.08
# Recall: 0.26666666666666666
# F1-score: 0.12307692307692308
# Confusion Matrix:
#  [[174  46]
#  [ 11   4]]
#
# Linear SVM | C=0.01 | class_weight={-1: 1, 1: 15}
# Accuracy: 0.6851063829787234
# Precision: 0.07246376811594203
# Recall: 0.3333333333333333
# F1-score: 0.11904761904761904
# Confusion Matrix:
#  [[156  64]
#  [ 10   5]]
#
# Linear SVM | C=0.01 | class_weight={-1: 1, 1: 20}
# Accuracy: 0.6553191489361702
# Precision: 0.07692307692307693
# Recall: 0.4
# ...

# %%
best_svm = SVC(
    kernel="linear",
    C=0.01,
    class_weight={-1:1, 1:5},
    random_state=RANDOM_SEED
)

best_svm.fit(X_train_scaled, y_train)
y_test_pred = best_svm.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_test_pred))
print("Precision:", precision_score(y_test, y_test_pred, pos_label=1, zero_division=0))
print("Recall:", recall_score(y_test, y_test_pred, pos_label=1, zero_division=0))
print("F1-score:", f1_score(y_test, y_test_pred, pos_label=1, zero_division=0))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Accuracy: 0.8983050847457628
# Precision: 0.3181818181818182
# Recall: 0.4375
# F1-score: 0.3684210526315789
# Confusion Matrix:
#  [[205  15]
#  [  9   7]]
